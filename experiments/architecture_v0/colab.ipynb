# %% [markdown]
# # IQ architecture v0 validation
#
# This notebook validates the recurrent IQ topology before any donor weights are inserted. It uses pinned research dependencies and can run on a normal Colab CPU runtime.

# %%
# !rm -rf /content/IQ
# !git clone --depth 1 --branch architecture/iq-research-v0 https://github.com/Harqer/IQ.git /content/IQ
# %cd /content/IQ

# %%
# !python -m pip install -q -r requirements-research.txt

# %%
# !python -m unittest tests.test_iq_model -v

# %%
# !python experiments/architecture_v0/validate_phi4_mini.py --donor microsoft/Phi-4-mini-instruct
