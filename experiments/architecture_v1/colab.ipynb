# %% [markdown]
# # IQ hybrid-v1 architecture validation
# Runs the architecture invariants, Phi-4-mini dimension checks, and CUDA smoke tests for Gated DeltaNet + NSA. No donor weights are loaded.

# %%
# !nvidia-smi || true
# !rm -rf IQ
# !git clone --depth 1 --branch architecture/iq-hybrid-v1 https://github.com/Harqer/IQ.git
# %cd IQ

# %%
# !python -m pip install --upgrade pip
# !python -m pip install -r requirements-hybrid.txt

# %%
import torch, transformers
print('torch', torch.__version__)
print('transformers', transformers.__version__)
print('cuda', torch.cuda.is_available())
if torch.cuda.is_available():
    print(torch.cuda.get_device_name(0))

# %%
# !python -m unittest tests.test_iq_model -v

# %%
# !python experiments/architecture_v1/validate_hybrid_phi4_mini.py

# %%
# !python -m unittest tests.test_hybrid_mixers -v
